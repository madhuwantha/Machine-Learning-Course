# %% [markdown]
# # Introduction to Matplotlib¶

# %% [markdown]
# #### Get straight into plotting data, that's what we're focused on.

# %% [markdown]
# ### 1. Concepts in Matplotlib
# ### 2. 2 ways of creating plots (pyplot & OO) - use the OO method
# ### 3. Plotting data (NumPy arrays), line, scatter, bar, hist, subplots
# ### 4. Plotting data directly with Pandas (using the pandas matplotlib wrapper)
# ### 5. Plotting data (pandas DataFrames) with the OO method, line, scatter, bar, hist, subplots
# ### 6. Cutomizing your plots, limits, colors, styles, legends
# ### 7. Saving plots

# %% [markdown]
# # 0. Concepts in Matplotlib

# %% [markdown]
# ### What is Matplotlib?
# ### Why Matplotlib?
# ### Anatomy of a figure
# ### Where does Matplotlib fit into the ecosystem?
# ### A Matplotlib workflow

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Create a simple plot, without the semi-colon
plt.plot()
# Out:
# []

# %%
plt.plot(); # With the semi-colon

# %%
# You could use plt.show() if you want
plt.plot()
plt.show()

# %%
# Let's add some data
plt.plot([1,2,3,4])

# %%
# Create some data
x = [1,2,3,4]
y = [11,22,33,44]

# %%
plt.plot(x,y)

# %%
# Creating a plot with the OO verison, confusing way first
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
# Confusing #2
fig = plt.figure()
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %%
# Easier and more robust going forward (what we're going to use)
fig, ax = plt.subplots()
ax.plot(x,y)

# %% [markdown]
# # -> Show figure/plot anatomy here <-

# %%
# A matplotlib workflow

# 0. Import and get matplotlib ready
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]


# 2. Setup plots
fig, ax  = plt.subplots(figsize=(10,10))

# 3. plot data
ax.plot(x,y)

# 4. Customize plot
ax.set(
    title="Samole Simple Plot", xlabel="x-axis",ylabel="y-axis"
)

# 5. Save & show
fig.savefig('Img/matplotlib/simple-plot.png')

# %% [markdown]
# # 2. Making the most common type of plots using NumPy arrays
#
# Most of figuring out what kind of plot to use is getting a feel for the data, then see what suits it best.
#
# Matplotlib visualizations are built off NumPy arrays. So in this section we'll build some of the most common types of plots using NumPy arrays.
#
# * line
# * scatter
# * bar
# * hist
# * subplots()
#
# To make sure we have access to NumPy, we'll import it as np.

# %%
import numpy as np

# %% [markdown]
# ## LIne
#
# Line is the default type of visualization in Matplotlib. Usually, unless specified otherwise, your plots will start out as lines.

# %%
# Create an array
x=np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# The default plot is line
fig, ax = plt.subplots()
ax.plot(x,x**2)

# %% [markdown]
# ## Scatter

# %%
# Need to recreate our figure and axis instances when we want a new figure
fig, ax = plt.subplots()
ax.scatter(x,np.exp(x))

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %% [markdown]
# ## Bar
#
#  * Vertical
#  * Horizontal

# %%
# You can make plots from a dictionary
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(
    title="Dan's Nut Butter Store",
    ylabel="Price ($)"
)
# Out:
# [Text(0, 0.5, 'Price ($)'), Text(0.5, 1.0, "Dan's Nut Butter Store")]

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## Histogram (hist)
#
#    * Could show image of normal distribution here

# %%
x = np.random.randn(1000);

fig, ax  = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Subplots
#
# * Multiple plots on one figure https://matplotlib.org/3.1.1/gallery/recipes/create_subplots.html

# %%
# Option 1: Create multiple subplots
fig, ((ax1,ax2) , (ax3,ax4)) = plt.subplots(
    ncols=2,
    nrows=2,
    figsize=(10,5)
)

#plot data
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax4.hist(np.random.random(1000));

# %%
# Option 2: Create multiple subplots
fig, ax = plt.subplots(
    ncols=2,
    nrows=2,
    figsize=(10,5)
)

# Index to plot data
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# # 3. Plotting data directly with pandas
#
# This section uses the pandas pd.plot() method on a DataFrame to plot columns directly.
#
# * https://datatofish.com/plot-dataframe-pandas/
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
#
# * line
# * scatter
# * bar
# * hist
# * df.plot(subplots=True, figsize=(6, 6))

# %%
# Let's import the car_sales dataset
car_sales = pd.read_csv("Data/PandasEx/car-sales-exported.csv")
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  Green          81155      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Line
#
# * Concept
# * DataFrame
#
# Often, reading things won't make sense. Practice writing code for yourself, get it out of the docs and into your workspace. See what happens when you run it.
#
# Let's start with trying to replicate the pandas visualization documents.

# %%
# Start with some dummy data
ts = pd.Series(np.random.random(1000),
              index=pd.date_range('1/1/2020',periods=1000)
              )
ts[:10]
# Out:
# 2020-01-01    0.432095
# 2020-01-02    0.616382
# 2020-01-03    0.212317
# 2020-01-04    0.710569
# 2020-01-05    0.237444
# 2020-01-06    0.168115
# 2020-01-07    0.790039
# 2020-01-08    0.344514
# 2020-01-09    0.846806
# 2020-01-10    0.439041
# Freq: D, dtype: float64

# %%
ts.cumsum()
# Out:
# 2020-01-01      0.432095
# 2020-01-02      1.048476
# 2020-01-03      1.260793
# 2020-01-04      1.971362
# 2020-01-05      2.208805
#                  ...
# 2022-09-22    488.244764
# 2022-09-23    488.781807
# 2022-09-24    489.555927
# 2022-09-25    490.126261
# 2022-09-26    490.911137
# Freq: D, Length: 1000, dtype: float64

# %%
ts.cumsum().plot()

# %% [markdown]
# ## Working with actual data
# Let's do a little data manipulation on our car_sales DataFrame.

# %%
# Remove price column symbols and Remove last two zeros
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','').str[:-2] 
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price
# 0           0  Toyota  White         150043      4   4000
# 1           1   Honda    Red          87899      4   5000
# 2           2  Toyota   Blue          32549      3   7000
# 3           3     BMW  Black          11179      5  22000
# 4           4  Nissan  Green          81155      4   3500
# 5           5  Toyota  Green          99213      4   4500
# 6           6   Honda   Blue          45698      4   7500
# 7           7   Honda   Blue          54738      4   7000
# 8           8  Toyota  White          60000      4   6250
# 9           9  Nissan  White          31600      4   9700

# %%
# Add a date column
car_sales["Sale Date"]= pd.date_range('1/1/2020',periods=len(car_sales))
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0           0  Toyota  White         150043      4   4000 2020-01-01
# 1           1   Honda    Red          87899      4   5000 2020-01-02
# 2           2  Toyota   Blue          32549      3   7000 2020-01-03
# 3           3     BMW  Black          11179      5  22000 2020-01-04
# 4           4  Nissan  Green          81155      4   3500 2020-01-05
# 5           5  Toyota  Green          99213      4   4500 2020-01-06
# 6           6   Honda   Blue          45698      4   7500 2020-01-07
# 7           7   Honda   Blue          54738      4   7000 2020-01-08
# 8           8  Toyota  White          60000      4   6250 2020-01-09
# 9           9  Nissan  White          31600      4   9700 2020-01-10

# %%
# Make total sales column (doesn't work, adds as string)
# car_sales["Total Sales"] = car_sales["Price"].cumsum()

# Oops... want them as int's not string
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price  Sale Date  \
# 0           0  Toyota  White         150043      4   4000 2020-01-01
# 1           1   Honda    Red          87899      4   5000 2020-01-02
# 2           2  Toyota   Blue          32549      3   7000 2020-01-03
# 3           3     BMW  Black          11179      5  22000 2020-01-04
# 4           4  Nissan  Green          81155      4   3500 2020-01-05
# 5           5  Toyota  Green          99213      4   4500 2020-01-06
# 6           6   Honda   Blue          45698      4   7500 2020-01-07
# 7           7   Honda   Blue          54738      4   7000 2020-01-08
# 8           8  Toyota  White          60000      4   6250 2020-01-09
# 9           9  Nissan  White          31600      4   9700 2020-01-10
#
#    Total Sales
# 0         4000
# 1         9000
# 2        16000
# 3        38000
# 4        41500
# 5        46000
# 6        53500
# 7        60500
# 8        66750
# 9        76450

# %%
car_sales.plot(x='Sale Date', y='Total Sales');

# %% [markdown]
# ## Scatter
#
# * Concept
# * DataFrame

# %%
car_sales.dtypes
# Out:
# Unnamed: 0                int64
# Make                     object
# Colour                   object
# Odometer (KM)             int64
# Doors                     int64
# Price                    object
# Sale Date        datetime64[ns]
# Total Sales               int64
# dtype: object

# %%
# Doesn't work
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")

# %% [markdown]
# ## Bar
# * Concept
# * DataFrame

# %%
x = np.random.rand(10,4)
x
# Out:
# array([[0.08976896, 0.17016342, 0.3769939 , 0.66458596],
#        [0.36526769, 0.70204698, 0.84891081, 0.84879865],
#        [0.3068343 , 0.75843259, 0.33540451, 0.2152943 ],
#        [0.56241146, 0.4769385 , 0.46936906, 0.17132118],
#        [0.94144561, 0.88014693, 0.87061264, 0.37981472],
#        [0.71552868, 0.58172091, 0.45590029, 0.35425898],
#        [0.80751482, 0.94818191, 0.44677501, 0.8531895 ],
#        [0.183863  , 0.6353242 , 0.1514162 , 0.96252023],
#        [0.1499548 , 0.36688352, 0.93707395, 0.91580497],
#        [0.3555915 , 0.63654994, 0.57242737, 0.4556007 ]])

# %%
df = pd.DataFrame(x,columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.089769  0.170163  0.376994  0.664586
# 1  0.365268  0.702047  0.848911  0.848799
# 2  0.306834  0.758433  0.335405  0.215294
# 3  0.562411  0.476939  0.469369  0.171321
# 4  0.941446  0.880147  0.870613  0.379815
# 5  0.715529  0.581721  0.455900  0.354259
# 6  0.807515  0.948182  0.446775  0.853189
# 7  0.183863  0.635324  0.151416  0.962520
# 8  0.149955  0.366884  0.937074  0.915805
# 9  0.355591  0.636550  0.572427  0.455601

# %%
df.plot.bar()

# %%
# Can do the same thing with 'kind' keyword
df.plot(kind="bar")

# %%
car_sales.plot(x='Make', y='Odometer (KM)',kind='bar')

# %% [markdown]
# ## Histograms

# %%
car_sales["Odometer (KM)"].plot.hist()

# %%
# Let's try with another dataset
hart_desease = pd.read_csv("Data/Matpotlib/heart-disease.csv.csv")
hart_desease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
hart_desease["age"].plot.hist(bins=50);

# %%
hart_desease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# ## Subplotsm
# * Concept
# * DataFrame

# %%
hart_desease.plot.hist(figsize=(10,30),subplots=True);

# %% [markdown]
# ## 4. Plotting with pandas using the OO method

# %% [markdown]
# For more complicated plots, you'll want to use the OO method.

# %%
hart_desease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
over_50 = hart_desease[hart_desease["age"] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [208 rows x 14 columns]

# %%
over_50.plot(
    kind='scatter',
    x='age',
    y='chol',
    c='target',
    figsize=(10,6)
);

# %%
#using OO method
fig, ax = plt.subplots(figsize=(10,6))

over_50.plot(kind="scatter",
             x="age",
             y="chol",
             c="target",
             ax=ax
            )
ax.set_xlim([45,100])
# Out:
# (45, 100)

# %%
# Make a bit more of a complicated plot

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(
    over_50["age"],
    over_50["chol"],
    c=over_50["target"]
)
# Customize the plot
ax.set(
    title="Heart Disease and Cholesterol Levels",
    xlabel="Age",
    ylabel="Cholesterol"
),
ax.legend(
    *scatter.legend_elements(),
    title="Target"
);

# %% [markdown]
# What if we wanted a horizontal line going across with the mean of heart_disease["chol"]?
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.axes.Axes.axhline.html

# %%
# Make a bit more of a complicated plot

# Make a bit more of a complicated plot

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(
    over_50["age"],
    over_50["chol"],
    c=over_50["target"]
)
# Customize the plot
ax.set(
    title="Heart Disease and Cholesterol Levels",
    xlabel="Age",
    ylabel="Cholesterol"
),
ax.legend(
    *scatter.legend_elements(),
    title="Target"
);

# Add a meanline
ax.axhline(over_50["chol"].mean(),linestyle="--")

# %% [markdown]
# ### Adding another plot to existing styled one¶

# %%
# Setup plot (2 rows, 1 column)
fig, (ax0,ax1)= plt.subplots(
    nrows=2,
    ncols=1,
    sharex=True,
    figsize=(10,8)
);

# Add data for ax0
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"])


# Add data for ax1
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"])





# Setup a mean line for ax0
ax0.axhline(y=over_50["chol"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")

# Setup a mean line for ax1
ax1.axhline(y=over_50["thalach"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")

# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(), title="Target")


# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(), title="Target")


# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# # 5. Customizing your plots
#
# * limits (xlim, ylim), colors, styles, legends

# %% [markdown]
# ## Style

# %%
plt.style.available
# Out:
# ['seaborn',
#  'seaborn-paper',
#  'seaborn-darkgrid',
#  'fast',
#  'dark_background',
#  'seaborn-dark',
#  'seaborn-ticks',
#  'seaborn-talk',
#  'seaborn-pastel',
#  'fivethirtyeight',
#  'ggplot',
#  'Solarize_Light2',
#  'seaborn-deep',
#  'seaborn-colorblind',
#  'seaborn-white',
#  'bmh',
#  'seaborn-whitegrid',
#  'seaborn-bright',
#  'grayscale',
#  'seaborn-poster',
#  'seaborn-dark-palette',
#  'seaborn-notebook',
#  '_classic_test',
#  'tableau-colorblind10',
#  'seaborn-muted',
#  'classic']

# %%
# Plot before changing style
car_sales["Price"].astype(int).plot();

# %%
# Change the style... 
plt.style.use('seaborn-whitegrid')

# %%
car_sales["Price"].astype(int).plot();

# %%
plt.style.use('seaborn')

# %%
car_sales["Price"].astype(int).plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.style.use('ggplot')

# %%
car_sales["Price"].astype(int).hist()

# %% [markdown]
# ## Changing the title, legend, axes

# %%
x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.90554012, -0.16766821,  1.26224676,  1.56186334],
#        [-0.77908677,  0.61036179,  0.00448679, -0.55959165],
#        [-1.05236149,  0.27411802,  0.59844482, -0.59505457],
#        [-0.07175153, -1.75692083,  0.49446446,  2.90157386],
#        [-1.24495319, -1.06237668,  1.74725651, -0.8001436 ],
#        [-0.28073426, -1.90130947, -0.38906509, -0.05010507],
#        [-0.90900059, -2.16987066,  0.97091785, -0.12422296],
#        [-0.16557054,  1.46573481,  2.03636546, -0.20416983],
#        [-0.13834326, -1.81390485,  0.60210844,  0.63229263],
#        [-1.12665143, -1.88572183,  1.22680733, -0.21857696]])

# %%
df = pd.DataFrame(x,columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.905540 -0.167668  1.262247  1.561863
# 1 -0.779087  0.610362  0.004487 -0.559592
# 2 -1.052361  0.274118  0.598445 -0.595055
# 3 -0.071752 -1.756921  0.494464  2.901574
# 4 -1.244953 -1.062377  1.747257 -0.800144
# 5 -0.280734 -1.901309 -0.389065 -0.050105
# 6 -0.909001 -2.169871  0.970918 -0.124223
# 7 -0.165571  1.465735  2.036365 -0.204170
# 8 -0.138343 -1.813905  0.602108  0.632293
# 9 -1.126651 -1.885722  1.226807 -0.218577

# %%
ax =df.plot(kind="bar")
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax = df.plot(kind='bar')
ax.set(
       stitle="Random Number Bar Graph from DataFrame", 
       xlabel="Row number", 
       ylabel="Random number")
ax.legend().set_visible(True)

# %% [markdown]
# ### Changing the cmap

# %%
plt.style.use('seaborn-whitegrid')

# %%
# No cmap change
fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"])

ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

ax.axhline(y=over_50["chol"].mean(), 
           c='b', 
           linestyle='--', 
           label="Average");

ax.legend(*scatter.legend_elements(), title="Target");

# %%
# Change cmap and horizontal line to be a different colour
fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"],
                     cmap="winter"
                    )

ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

ax.axhline(y=over_50["chol"].mean(), 
           c='b', 
           linestyle='--', 
           label="Average");

ax.legend(*scatter.legend_elements(), title="Target");

# %% [markdown]
# ### Changing the xlim & ylim¶

# %%
## Before the change (we've had color updates)
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 10))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax1.legend(*scatter.legend_elements(), title="Target")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %%
## After adding in different x & y limitations
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 10))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")

# Set the x axis
ax0.set_xlim([50, 80])

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax1.legend(*scatter.legend_elements(), title="Target")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');


# Set the y axis
ax1.set_ylim([60, 200])
# Out:
# (60, 200)

# %% [markdown]
# # 6. Saving plots
#
# * Saving plots to images using figsave()
#
# If you're doing something like this often, to save writing excess code, you might put it into a function.
#
# A function which follows the Matplotlib workflow.

# %%
# Save the file
fig.savefig("Img/matplotlib/heart-disease-analysis.png")
